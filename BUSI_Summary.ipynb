# %%
from IPython.display import Image
Image(filename="BUSI.png",width=700,height=700)

# %%
Image(filename="BUSI_Resnet50.png",width=700,height=700)

# %%
Image(filename="VGG11+Data_Augmentation.png",width=700,height=700)

# %%
Image(filename="VGG11_Original.png",width=700,height=700)

# %%
Image(filename="CNN.png",width=700,height=700)
